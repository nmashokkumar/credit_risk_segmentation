# %% [markdown]
# ## Import Packages

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Perform EDA and Feature Engineering

# %%
df = pd.read_csv("default of credit card clients.csv", header = 1)

print(df.shape)
df.head()
# Out:
# (30000, 25)
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.drop('ID', axis=1, inplace=True)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df['de_pay_next_month'] = df['default payment next month']

# %%
df.drop(df['default payment next month'], axis=0, inplace=True)

# %%
df.tail()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 29995      0  ...      31237      15980      8500     20000      5003
# 29996      0  ...       5190          0      1837      3526      8998
# 29997      0  ...      20582      19357         0         0     22000
# 29998      0  ...      11855      48944     85900      3409      1178
# 29999      0  ...      32428      15313      2078      1800      1430
#
#        PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month  \
# ...

# %%
df.de_pay_next_month.value_counts()
# Out:
# de_pay_next_month
# 0    23364
# 1     6634
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# de_pay_next_month             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(35)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (29963, 25)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Statistical Analysis

# %%
pay_columns = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
bill_columns = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
pay_amt = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5' ,'PAY_AMT6']

# %%
df[pay_columns].skew()
# Out:
# PAY_0    0.734650
# PAY_2    0.792275
# PAY_3    0.841412
# PAY_4    1.000751
# PAY_5    1.009407
# PAY_6    0.948768
# dtype: float64

# %%
df[bill_columns].skew()
# Out:
# BILL_AMT1    2.662426
# BILL_AMT2    2.703776
# BILL_AMT3    3.086411
# BILL_AMT4    2.820458
# BILL_AMT5    2.874835
# BILL_AMT6    2.845045
# dtype: float64

# %%
df[pay_amt].skew()
# Out:
# PAY_AMT1    14.661211
# PAY_AMT2    30.437702
# PAY_AMT3    17.207676
# PAY_AMT4    12.898122
# PAY_AMT5    11.121420
# PAY_AMT6    10.634756
# dtype: float64

# %%
plt.hist(df.LIMIT_BAL, bins=20, rwidth=0.8,  )
# Out:
# (array([7.672e+03, 4.817e+03, 3.896e+03, 3.970e+03, 2.900e+03, 2.153e+03,
#         1.206e+03, 1.546e+03, 5.730e+02, 1.024e+03, 7.600e+01, 5.100e+01,
#         3.700e+01, 1.900e+01, 1.700e+01, 5.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  10000.,   59500.,  109000.,  158500.,  208000.,  257500.,
#          307000.,  356500.,  406000.,  455500.,  505000.,  554500.,
#          604000.,  653500.,  703000.,  752500.,  802000.,  851500.,
#          901000.,  950500., 1000000.]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df.AGE, bins=20, rwidth=0.8,  )
# Out:
# (array([1.557e+03, 3.561e+03, 4.483e+03, 3.764e+03, 3.420e+03, 3.091e+03,
#         2.643e+03, 2.161e+03, 1.688e+03, 9.150e+02, 1.055e+03, 7.810e+02,
#         4.220e+02, 2.060e+02, 1.060e+02, 6.500e+01, 3.000e+01, 1.000e+01,
#         4.000e+00, 1.000e+00]),
#  array([21. , 23.9, 26.8, 29.7, 32.6, 35.5, 38.4, 41.3, 44.2, 47.1, 50. ,
#         52.9, 55.8, 58.7, 61.6, 64.5, 67.4, 70.3, 73.2, 76.1, 79. ]),
#  <BarContainer object of 20 artists>)

# %%
# Compute correlation matrix
corr_matrix = df.corr()

# Set up the plot size
plt.figure(figsize=(14, 10))

# Create the heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)

plt.title("Correlation Heatmap of Credit Dataset Features")
plt.show()

# %% [markdown]
# ## Model Building

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'de_pay_next_month'],
#       dtype='object')

# %%
cols =['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT6',
             'PAY_AMT1','PAY_AMT6']

feature = df[cols]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(feature)

# %% [markdown]
# ## KMeans Elbow Method

# %%
inertia = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)  # Use standardized data
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8,5))
plt.plot(K, inertia, 'bo-', markersize=8)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 0    15522
# 1    10327
# 2     4114
# Name: count, dtype: int64

# %%
cluster_profile = df.groupby('Cluster').mean()
print(cluster_profile[['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_AMT1', 'PAY_AMT6']])
# Out:
#              LIMIT_BAL        AGE     PAY_0     PAY_2      PAY_AMT1  \
# Cluster
# 0         98572.477773  34.372761  0.437315  0.480028   3320.835266
# 1        221021.593880  36.465576 -0.780769 -1.165779   4871.472838
# 2        292836.091395  37.246719  0.187652  0.153865  16541.278804
#
#              PAY_AMT6
# Cluster
# 0         2600.330756
# 1         5057.603273
# 2        15524.546670

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=df['Cluster'], cmap='viridis', s=10)
plt.title('KMeans Clusters (k=3)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
cluster_labels = {0: 'Low Risk', 1: 'Medium Risk', 2: 'High Risk'}
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=df['Cluster'], cmap='viridis', s=10)
plt.title('KMeans Clusters Visualized with PCA (k=3)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %% [raw]
# 🟢 Green: Low Risk Customers
#
# 🟡 Yellow: Medium Risk Customers
#
# 🟣 Purple: High Risk Customers
